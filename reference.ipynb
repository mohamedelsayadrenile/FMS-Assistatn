# %%
import httpx

url = "https://agridafter.com/api/task-types"

jwt_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....DQE0su0-XcEeSlr5ItefpHjm3ecnp3wWKPWreRG8J4o"

payload = {
    "title": "Irrigating the grapes",
    "description": "the employee is irrigating the grapes",
    "input_type": "number", # allowed types: ["string","number","image","checkbox","select"]
    "farm_type": "greenhouse", # allowed types: ["greenhouse","traditional_land","trees"]
    "input_config": {
        "options": [ # the options should be filled with valid values only if the input_type is "select"
            ""
        ]
    }
}

headers = {
    "Content-Type": "application/json",
    "Accept": "application/json",
    "Authorization": f"JWT {jwt_token}"
}

try:
    response = httpx.get(
        url,
        headers=headers,
        timeout=30
    )

    print("Status Code:", response.status_code)

    try:
        print("Response:", response.json())
    except ValueError:
        print("Non-JSON response:")
        print(response.text)

except httpx.HTTPError as e:
    print("Request failed:", str(e))
# Out:
# Status Code: 200
# ...

# %%
import httpx

siteId = "c5111a37-9812-4300-aa10-afeebb2d8885"

url = f"https://agridafter.com/api/sites/{siteId}/farms"

jwt_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....M2SgZkl2DeuPmzRmG_Jr3_IxxXiJcFmT4O0COGCH3gI"

payload = {
    "farm_name": "apple",
    "farmType": "trees", # there is 3 allowed types of farmType, [traditional_land,greenhouse,trees]
    "location": "",
      "initialData": {
        "area": {
            "value": "12",
            "unit": "hectares"
        },
        "tree_species": "Orange",
        "planting_date": "2026-07-09",
        "number_of_trees": 100
    },
    "initialNumber": "null",
    "farmAge": "null"
}

headers = {
    "Content-Type": "application/json",
    "Accept": "application/json",
    "Authorization": f"JWT {jwt_token}"
}

try:
    response = httpx.post(
        url,
        json=payload,
        headers=headers,
        timeout=30
    )

    print("Status Code:", response.status_code)

    try:
        print("Response:", response.json())
    except ValueError:
        print("Non-JSON response:")
        print(response.text)

except httpx.HTTPError as e:
    print("Request failed:", str(e))
# Out:
# Status Code: 201
# ...
