# %%
import httpx

url = "https://agridafter.com/api/auth/otp/send"

payload = {
    "phone": "+201033618792"
}

headers = {
    "Content-Type": "application/json",
    "Accept": "application/json"
}

try:
    response = httpx.post(
        url,
        json=payload,
        headers=headers,
        timeout=30
    )

    print("Status Code:", response.status_code)
    print("Response:", response.json())

except httpx.HTTPError as e:
    print("Request failed:", str(e))
except ValueError:
    print("Non-JSON response:")
    print(response.text)
# Out:
# Status Code: 200
# Response: {'message': 'OTP sent successfully via WhatsApp', 'message_ar': 'تم إرسال رمز التحقق بنجاح عبر الواتساب'}

# %%
import httpx

url = "https://agridafter.com/api/auth/otp/verify"

payload = {
    "phone": "+201033618792",
    "code": "430043",
    "timezone": "Africa/Cairo"
}

headers = {
    "Content-Type": "application/json",
    "Accept": "application/json"
}

try:
    response = httpx.post(
        url,
        json=payload,
        headers=headers,
        timeout=30
    )

    print("Status Code:", response.status_code)

    try:
        print("Response:", response.json())
    except ValueError:
        print("Non-JSON response:")
        print(response.text)

except httpx.HTTPError as e:
    print("Request failed:", str(e))
# Out:
# Status Code: 200
# Response: {'status': 'login_success', 'user': {'id': '9e91204a-d03d-46cd-83b5-a5b40ff36e5e', 'role': 'OWNER', 'phone': '+201033618792', 'company_id': '0e5c556f-b352-4970-a4e3-f32a465eb12f', 'is_active': True, 'created_at': '2026-07-08T05:32:16.189Z', 'updated_at': '2026-07-08T06:00:10.602Z', 'is_verified': True, 'username': None, 'timezone': 'Africa/Cairo', 'admin_role': None, 'name': 'Mohamed', 'avatar': None, 'email': 'mohamed.elsayed@renile.net', 'company': {'id': '0e5c556f-b352-4970-a4e3-f32a465eb12f', 'name': 'Acme Corp', 'registration_number': 'REG1783488736190', 'contact_email': 'mohamed.elsayed@renile.net', 'contact_phone': '+201033618792', 'address_line1': None, 'address_line2': None, 'city': None, 'state': None, 'postal_code': None, 'country': None, 'tax_id': None, 'business_type': None, 'industry': None, 'employee_count': None, 'website': None, 'logo_url': None, 'subscription_status': 'active', 'subscription_plan': 'basic', 'subscription_start_date': None, 'subscription_end_date': None, 'billing_cycle': 'monthly', 'is_active': True, 'created_at': '2026-07-08T05:32:16.189Z', 'updated_at': '2026-07-08T05:32:16.189Z', 'suspended_at': None, 'suspended_by': None, 'suspension_reason': None, 'max_farms': 10, 'max_warehouses': 5, 'max_employees': 50, 'max_managers': 10, 'max_sites': 1}, 'employee_id': None}, 'token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....B195RPYviWY2XQqo-VpIWsGFCF0zykJM7DhR9m4YfIU'}

# %%
import httpx

url = "https://agridafter.com/api/sites"

jwt_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....B195RPYviWY2XQqo-VpIWsGFCF0zykJM7DhR9m4YfIU"

payload = {
    "name": "Al-Ahliyya Farm Complex",
    "companyId": "0e5c556f-b352-4970-a4e3-f32a465eb12f",
    "type": "farm",
    "location": "Sadat City, Egypt",
    "timezone": "Africa/Cairo",
    "managerIds": [
        "9e91204a-d03d-46cd-83b5-a5b40ff36e5e"
    ]
}

headers = {
    "Content-Type": "application/json",
    "Accept": "application/json",
    "Authorization": f"JWT {jwt_token}"
}

try:
    response = httpx.post(
        url,
        json=payload,
        headers=headers,
        timeout=30
    )

    print("Status Code:", response.status_code)

    try:
        print("Response:", response.json())
    except ValueError:
        print("Non-JSON response:")
        print(response.text)

except httpx.HTTPError as e:
    print("Request failed:", str(e))
# Out:
# Status Code: 201
# Response: {'id': '73d6b79e-2327-4f0d-893a-2eef9663d208', 'name': 'Al-Ahliyya Farm Complex', 'code': None, 'type': 'farm', 'companyId': '0e5c556f-b352-4970-a4e3-f32a465eb12f', 'companyName': 'Acme Corp', 'location': 'Sadat City, Egypt', 'latitude': None, 'longitude': None, 'governorate': None, 'city': None, 'street': None, 'district': None, 'managers': [{'id': '9e91204a-d03d-46cd-83b5-a5b40ff36e5e', 'manager_name': 'Mohamed', 'can_add_employees': False}], 'can_manage_warehouse': True, 'timezone': 'Africa/Cairo', 'createdAt': '2026-07-08T06:15:36.383Z', 'updatedAt': '2026-07-08T06:15:36.383Z'}

# %%
from openai import OpenAI

client = OpenAI(
    base_url="http://localhost:11434/v1",
    api_key="00731b2500184c209fb2ba74183d45ef.hN512Ah2FMZ5m0hKp1e3YHgT"  # required by OpenAI SDK, ignored by Ollama
)

response = client.chat.completions.create(
    model="gpt-oss:120b-cloud",  # replace with your local Ollama model name
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Hello, explain IoT in one sentence."}
    ],
)

print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[2], line 8
#       4     base_url="http://localhost:11434/v1",
#       5     api_key="00731b2500184c209fb2ba74183d45ef.hN512Ah2FMZ5m0hKp1e3YHgT"  # required by OpenAI SDK, ignored by Ollama
#       6 )
#       7
# ----> 8 response = client.chat.completions.create(
#       9     model="gpt-oss:120b-cloud",  # replace with your local Ollama model name
#      10     messages=[
#      11         {"role": "system", "content": "You are a helpful assistant."},
#
# File ~/Desktop/projects/FMS-Assistant/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File ~/Desktop/projects/FMS-Assistant/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1251, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1203 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1204 def create(
#    1205     self,
#    (...)   1248     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1249 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1250     validate_response_format(response_format)
# -> 1251     return self._post(
#    1252         "/chat/completions",
#    1253         body=maybe_transform(
#    1254             {
#    1255                 "messages": messages,
#    1256                 "model": model,
#    1257                 "audio": audio,
#    1258                 "frequency_penalty": frequency_penalty,
#    1259                 "function_call": function_call,
#    1260                 "functions": functions,
#    1261                 "logit_bias": logit_bias,
#    1262                 "logprobs": logprobs,
#    1263                 "max_completion_tokens": max_completion_tokens,
#    1264                 "max_tokens": max_tokens,
#    1265                 "metadata": metadata,
#    1266                 "modalities": modalities,
#    1267                 "moderation": moderation,
#    1268                 "n": n,
#    1269                 "parallel_tool_calls": parallel_tool_calls,
#    1270                 "prediction": prediction,
#    1271                 "presence_penalty": presence_penalty,
#    1272                 "prompt_cache_key": prompt_cache_key,
#    1273                 "prompt_cache_retention": prompt_cache_retention,
#    1274                 "reasoning_effort": reasoning_effort,
#    1275                 "response_format": response_format,
#    1276                 "safety_identifier": safety_identifier,
#    1277                 "seed": seed,
#    1278                 "service_tier": service_tier,
#    1279                 "stop": stop,
#    1280                 "store": store,
#    1281                 "stream": stream,
#    1282                 "stream_options": stream_options,
#    1283                 "temperature": temperature,
#    1284                 "tool_choice": tool_choice,
#    1285                 "tools": tools,
#    1286                 "top_logprobs": top_logprobs,
#    1287                 "top_p": top_p,
#    1288                 "user": user,
#    1289                 "verbosity": verbosity,
#    1290                 "web_search_options": web_search_options,
#    1291             },
#    1292             completion_create_params.CompletionCreateParamsStreaming
#    1293             if stream
#    1294             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1295         ),
#    1296         options=make_request_options(
#    1297             extra_headers=extra_headers,
#    1298             extra_query=extra_query,
#    1299             extra_body=extra_body,
#    1300             timeout=timeout,
#    1301             security={"bearer_auth": True},
#    1302         ),
#    1303         cast_to=ChatCompletion,
#    1304         stream=stream or False,
#    1305         stream_cls=Stream[ChatCompletionChunk],
#    1306     )
#
# File ~/Desktop/projects/FMS-Assistant/.venv/lib/python3.12/site-packages/openai/_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Desktop/projects/FMS-Assistant/.venv/lib/python3.12/site-packages/openai/_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': 'Unauthorized'}
